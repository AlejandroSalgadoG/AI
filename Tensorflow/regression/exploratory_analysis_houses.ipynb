# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("../materials/DATA/kc_house_data.csv")
data.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
numeric_cols = [
    'price',
    'sqft_living',
    'sqft_lot',
    'sqft_above',
    'sqft_basement',
    'sqft_living15', 
    'sqft_lot15'
]
numeric_data = data[numeric_cols]
numeric_data.head()
# Out:
#       price  sqft_living  sqft_lot  sqft_above  sqft_basement  sqft_living15  \
# 0  221900.0         1180      5650        1180              0           1340
# 1  538000.0         2570      7242        2170            400           1690
# 2  180000.0          770     10000         770              0           2720
# 3  604000.0         1960      5000        1050            910           1360
# 4  510000.0         1680      8080        1680              0           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503

# %%
numeric_data.describe().T
# Out:
#                  count           mean            std      min       25%  \
# price          21597.0  540296.573506  367368.140101  78000.0  322000.0
# sqft_living    21597.0    2080.321850     918.106125    370.0    1430.0
# sqft_lot       21597.0   15099.408760   41412.636876    520.0    5040.0
# sqft_above     21597.0    1788.596842     827.759761    370.0    1190.0
# sqft_basement  21597.0     291.725008     442.667800      0.0       0.0
# sqft_living15  21597.0    1986.620318     685.230472    399.0    1490.0
# sqft_lot15     21597.0   12758.283512   27274.441950    651.0    5100.0
#
#                     50%       75%        max
# price          450000.0  645000.0  7700000.0
# sqft_living      1910.0    2550.0    13540.0
# sqft_lot         7618.0   10685.0  1651359.0
# sqft_above       1560.0    2210.0     9410.0
# sqft_basement       0.0     560.0     4820.0
# sqft_living15    1840.0    2360.0     6210.0
# sqft_lot15       7620.0   10083.0   871200.0

# %%
sns.heatmap(numeric_data.corr(), annot=True, cmap='BrBG')
# Out:
# <Axes: >

# %%
sns.displot(data['price'])

# %%
common_price_data = data[data["price"] < 3e6]
print(common_price_data.shape)
sns.displot(common_price_data['price'])
# Out:
# (21546, 21)

# %%
sns.scatterplot(x='price',y='sqft_living',data=common_price_data)
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
sns.countplot(common_price_data, x='bedrooms')
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
sns.boxplot(x='bedrooms',y='price',data=common_price_data)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
sns.scatterplot(x='long', y='lat',data=common_price_data, hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>
